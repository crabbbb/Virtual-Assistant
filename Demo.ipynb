# %% [markdown]
# ## Installation of API / Package

# %%
pip install SpeechRecognition
# Out:
# ...
#   Obtaining dependency information for SpeechRecognition from https://files.pythonhosted.org/packages/9e/e9/edd24b7000e209f34b5f7d13daa05337a1c306b120c0b92bb24e4527d579/SpeechRecognition-3.10.3-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/32.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.8 MB 991.0 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/32.8 MB 1.8 MB/s eta 0:00:19
#    ---------------------------------------- 0.4/32.8 MB 3.3 MB/s eta 0:00:10
#     --------------------------------------- 0.6/32.8 MB 3.7 MB/s eta 0:00:09
#    - -------------------------------------- 0.8/32.8 MB 3.5 MB/s eta 0:00:10
#    - -------------------------------------- 1.1/32.8 MB 3.8 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/32.8 MB 4.1 MB/s eta 0:00:08
#    - -------------------------------------- 1.5/32.8 MB 4.1 MB/s eta 0:00:08
# ...

# %%
pip install PyAudio
# Out:
# ...
#   Obtaining dependency information for PyAudio from https://files.pythonhosted.org/packages/82/d8/f043c854aad450a76e476b0cf9cda1956419e1dacf1062eb9df3c0055abe/PyAudio-0.2.14-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/164.1 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/164.1 kB ? eta -:--:--
#    --------- ----------------------------- 41.0/164.1 kB 667.8 kB/s eta 0:00:01
#    --------------------------- ------------ 112.6/164.1 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 164.1/164.1 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Speech to Text

# %%
import speech_recognition as speech

recognizer = speech.Recognizer()

def capture_voice_input():
    with speech.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)
    return audio

# %%
def convert_voice_to_text(audio):
    try:
        text = recognizer.recognize_google(audio)
        print("You said: " + text)
    except speech.UnknownValueError:
        text = ""
        print("Sorry, I didn't understand that.")
    except speech.RequestError as e:
        text = ""
        print("Error; {0}".format(e))
    return text

# %%
# audio capture will be stop when people stop talking 
audio = capture_voice_input()
print("listen end... start processing")
text = convert_voice_to_text(audio)
print(text)
# Out:
# Listening...
# listen end... start processing
# Sorry, I didn't understand that.

# %% [markdown]
# * speech to text
# [Different kind of recognizer](https://github.com/Uberi/speech_recognition/blob/master/examples/microphone_recognition.py)
